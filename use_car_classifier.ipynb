# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
path = Path()
path.ls(file_exts='.pkl')
learn_inf = load_learner(path/'model.pkl')

# %%
file = 'car.jpeg'
im = Image.open(file)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F99C9F37F50>

# %%
learn_inf.predict(file)
# Out:
# ('audi',
#  tensor(3),
#  tensor([4.3230e-04, 8.2830e-05, 4.3211e-05, 9.7037e-01, 1.8522e-04, 1.0684e-03, 2.8478e-04, 1.8766e-04, 3.9855e-04, 7.8719e-04, 1.5758e-04, 4.0063e-05, 3.7206e-05, 1.8370e-06, 4.4070e-04, 1.4894e-04,
#          5.8975e-04, 1.1722e-04, 2.3264e-05, 7.5434e-03, 5.4779e-04, 3.2791e-03, 3.6676e-05, 7.0786e-04, 9.8088e-05, 7.0078e-05, 2.7942e-04, 7.5363e-04, 2.4480e-05, 9.6115e-05, 2.5045e-04, 2.5852e-05,
#          6.2318e-04, 7.4656e-06, 3.0264e-04, 4.0780e-05, 2.7961e-04, 6.5394e-05, 1.8577e-04, 5.0545e-03, 1.6176e-04, 1.5817e-04, 1.0778e-04, 7.1101e-05, 4.5943e-04, 6.2051e-06, 2.6145e-05, 1.4259e-03,
#          2.9135e-06, 1.8917e-04, 1.7197e-03]))
